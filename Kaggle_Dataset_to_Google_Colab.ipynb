# %% [markdown]
# <a href="https://colab.research.google.com/github/sac-1999/Kaggle-Datasets-to-Colab/blob/main/Kaggle_Dataset_to_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Step 1:Get you Kaggle API Token
#
#
# *   Go to Your Account and click on Create New API Token.
# *   A file named kaggle.json will get downloaded containing your username and
#     token key
#
# ![image.png](data:image/png;base64,...)
#
# ### Step 2: Uploading kaggle.json into Google Drive
#
#
#
# *   Create a folder named Kaggle where we will be storing our Kaggle datasets
# *   Upload your kaggle.json file into Kaggle folder
#
# ![image.png](data:image/png;base64,...)
#
#
# ### Step 3: Create a new Colab notebook
#
#
# ### Step 4: Mount the drive to colab notebook
# Use the below code to mount your google drive
#
#
# *   from google.colab import drive
# *   drive.mount('/content/gdrive')
#
#
#
#
#
# Get your authorization code using the URL prompted and provide it in the empty box as shown in figure
#
# ![image.png](data:image/png;base64,...)
#
# ### Step 4: Run the following code to provide the config path to kaggle.json
#
# ####### import os
# ####### os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"
# ###### /content/gdrive/My Drive/Kaggle is the path where kaggle.json is present in the Google Drive
# ### Step 5: Change your present working directory
# ###### changing the working directory
# %cd /content/gdrive/My Drive/Kaggle
# ###### Check the present working directory using pwd command

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"
# /content/gdrive/My Drive/Kaggle is the path where kaggle.json is present in the Google Drive

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Kaggle
#Check the present working directory using pwd command
# Out:
# /content/gdrive/My Drive/Kaggle

# %%
# Go to kaggle dataset and copy API command using ! in start run the copied command
! kaggle datasets download -d mriganksingh/football-header
# Out:
# Downloading football-header.zip to /content/gdrive/My Drive/Kaggle
#   0% 0.00/2.67M [00:00<?, ?B/s]
# 100% 2.67M/2.67M [00:00<00:00, 43.6MB/s]

# %%
#unzipping the zip files and deleting the zip files
# !unzip \*.zip  && rm *.zip
# Out:
# Archive:  football-header.zip
#   inflating: data.mat
#   inflating: test_catvnoncat.h5
#   inflating: train_catvnoncat.h5
